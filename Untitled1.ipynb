# %%
import numpy as np
import pandas as pd
import requests
import os 
import math
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
from mpl_toolkits.mplot3d import Axes3D
from scipy import interpolate
from scipy.interpolate import griddata

# %% [markdown]
# ## Aproximación de Geodésicas

# %%
rs=1
m=rs/2
d=2
k=0
l=7                              
ti=np.arctan(d/(l/2))

# %%
a=0
def eqq(d,k,m):
    r=np.zeros(1000)
    phi=np.linspace(0,np.pi,1000)
    for i in range(len(r)):
        r[i]=(d**2)/(d*np.sin(phi[i]-a)+m*(1+k*np.cos(phi[i]-a)+np.cos(phi[i]-a)**2)) 
    y=r*np.sin(phi)
    x=r*np.cos(phi)
    return x,y
A=eqq(d,k,m)
B=eqq(2,k,m)
C=eqq(4,k,m)

# %%
plt.figure(figsize=(7,5))
plt.axhline(y=3*np.sqrt(3)*rs/2, xmin=-5, xmax=5,color='yellow',label="Recta")
plt.plot(A[0],A[1],color='red',label="Trayectoria fotón")
plt.axvline(x=0, ymin=0.6, ymax=0.76)
draw_circle = plt.Circle((0.0, 0.0), 2*m,fill=False, color='black',linewidth=2, linestyle="solid")
plt.annotate(r'$b$',xy=(0.1, 1.5), xycoords='data', fontsize=10)
plt.text(-4.9, 4.5, "b)",fontsize=14)
plt.annotate(r'$r_s$',xy=(1.1, 0), xycoords='data', fontsize=10)
plt.gcf().gca().add_artist(draw_circle)
plt.xlabel('x')
plt.ylabel('y')
plt.xlim(-5,5)#
plt.ylim(-5,5)
plt.legend(loc='lower left')
plt.savefig('rrr.pdf')

# %% [markdown]
# ## Pontencial Efectivo

# %%
r1 = np.linspace(0, 10, 100)
v=np.zeros(len(r1))
rs=1
q=1/2
for k in range(len(r1)):
    v[k]=(1/r1[k])*np.sqrt(1-rs/r1[k]+q**2/r1[k]**2)


plt.figure(figsize=(7,5))
plt.title("",fontsize=18, color = 'black')  
plt.plot(r1,v, color='black',linewidth=2.5)
plt.xlim(0,10)
plt.ylim(0, 0.6)
plt.axhline(y=0.5, xmin=0, xmax=5,color='red', linewidth=2)
plt.axhline(y=np.max(v), xmin=0.15, xmax=5,color='green', linewidth=2)
plt.axhline(y=.2, xmin=0.45, xmax=5, color='blue', linewidth=2)
plt.annotate(r'$b<b_c$',xy=(8, 0.52), xycoords='data', fontsize=10)
plt.annotate(r'$b=b_c$',xy=(8, 0.4), xycoords='data', fontsize=10)
plt.annotate(r'$b>b_c$',xy=(8, 0.22), xycoords='data', fontsize=10)
plt.text(0.1, 0.57, "a)",fontsize=14)
#plt.axvline(x=3.5, ymin=-5, ymax=5)
plt.xlabel("$r/r_s$",fontsize=15, color = 'black')            
plt.ylabel("$V/V_0$",fontsize=15, color = 'black')   
#plt.grid(color = '0.5', linestyle = '--', linewidth = 1)
plt.savefig('potencial.pdf')
# Out:
# /Users/marco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in double_scalars
#
# /Users/marco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in double_scalars
#
# /Users/marco/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %%
r1 = np.linspace(0, 10, 1000)
v1=np.zeros(len(r1))
v2=np.zeros(len(r1))
v3=np.zeros(len(r1))
S=np.zeros(len(r1))
rs=1
q1=.4*rs
q2=1/2*rs
q3=.7*rs
for k in range(len(r1)):
    v1[k]=(1-rs/r1[k]+q1**2/r1[k]**2)
    v2[k]=(1-rs/r1[k]+q2**2/r1[k]**2)
    v3[k]=(1-rs/r1[k]+q3**2/r1[k]**2)
    S[k]=(1-rs/r1[k])
    


plt.figure(figsize=(7,5))
plt.title("",fontsize=18, color = 'black')  
plt.plot(r1,v1, color='red',linewidth=2.5, label=r'$q<r_s/2$')
plt.plot(r1,v3, color='green',linewidth=2.5, label=r'$q>r_s/2$')
plt.plot(r1,v2, color='blue',linewidth=2.5, label=r'$q=r_s/2$')
plt.plot(r1,S, color='black',linewidth=2.5, label=r'$q=0\ \ \to \ \ Schwarzschild$')
plt.axhline(y=0.0, xmin=0, xmax=5,color='black', linewidth=2)
#plt.xlabel("$r/r_s$",fontsize=15, color = 'black')            
#plt.ylabel("$V/V_0$",fontsize=15, color = 'black') 
#plt.axvline(x=rs/2, ymin=-5, ymax=5)

plt.annotate(r'$r-$',xy=(0.10, -0.07), xycoords='data', fontsize=13)
plt.annotate(r'$r+$',xy=(0.76, -0.085), xycoords='data', fontsize=13)
plt.annotate(r'$r_s$',xy=(1, -0.07), xycoords='data', fontsize=13)
plt.annotate(r'$\frac{r_s}{2}$',xy=(.5, 0.07), xycoords='data', fontsize=15)
plt.annotate(r'$r$',xy=(1.9, -0.08), xycoords='data', fontsize=16)
plt.annotate(r'$>$',xy=(1.94, -0.035), xycoords='data', fontsize=16)

ax = plt.axes()
ax.spines['bottom'].set_linewidth(2)
ax.spines['left'].set_linewidth(2)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)


ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks([0, 0, np.pi, 3*np.pi/2, 2*np.pi])
ax.xaxis.set_ticklabels(['$\ $', '$\ $', '$\ $', '$\ $', '$r/r_s$'])
ax.yaxis.set_ticks([-1,-0.5,0,0.5,1])
ax.yaxis.set_ticklabels(['$\ $', '$\ $', '$\ $', '$\ $', '$\ $' '$g_{tt}$'])
ax.tick_params(labelsize=14)

ax = plt.gca()  # gca stands for 'get current axis'
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

plt.xlim(0,2)
plt.ylim(-0.8, 1)
plt.legend(loc='lower right')
plt.savefig('Horizontes.pdf')
# Out:
# /Users/marco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in double_scalars
#   # This is added back by InteractiveShellApp.init_path()
# /Users/marco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in double_scalars
#   # This is added back by InteractiveShellApp.init_path()
# /Users/marco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in double_scalars
#   if sys.path[0] == '':
# /Users/marco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in double_scalars
#   if sys.path[0] == '':
# /Users/marco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: divide by zero encountered in double_scalars
#   del sys.path[0]
# ...

# %% [markdown]
# ## RK para geodesica de Schwarzchild y Reissner-Nordstrom

# %%
def geodesicas(d,l,rs,n,ti,tf,z0,y0,q): 
    h=(tf-ti)/n  
    time1=list(range(0,n+1));
    y=list(range(0,n+1)) 
    z=list(range(0,n+1))
    r=list(range(0,n+1))
    y[0]=y0
    z[0]=z0 
    r[0]=1/z0
    time1[0]=ti
    m=rs/2
    rh=rs/2+np.sqrt(rs**2-4*q**2)/2
    for i in range(0,len(time1)-1):
        time1[i+1]=time1[i]+h
        k1=h*y[i]           
        l1=h*(3*m*z[i]**2-z[i]-2*(q**2)*(z[i]**3))  
        k2=h*(y[i]+l1/2)      
        l2=h*(3*m*(z[i]+k1/2)**2-(z[i]+k1/2)-2*(q**2)*((z[i]+k1/2)**3))   
        k3=h*(y[i]+l2/2)      
        l3=h*(3*m*(z[i]+k2/2)**2-(z[i]+k2/2)-2*(q**2)*((z[i]+k2/2)**3))
        k4=h*(y[i]+l3)      
        l4=h*(3*m*(z[i]+k3/2)**2-(z[i]+k3/2)-2*(q**2)*((z[i]+k3/2)**3))
        z[i+1]=(z[i]+(1/6)*(k1+2*k2+2*k3+k4))
        y[i+1]=y[i]+(1/6)*(l1+2*l2+2*l3+l4)
        r[i+1]=1/z[i]

    x_graf=r*np.cos(time1)
    y_graf=r*np.sin(time1)
    for j in range(0,len(time1)-1):
        #if x_graf[j]<-l/2 or y_graf[j]<-l/2 or r[j]<1 or x_graf[j]>l/2 or y_graf[j]>l/2:
        if r[j]<rh:
            x_graf[j]=np.nan
            y_graf[j]=np.nan
    return x_graf,y_graf,time1

# %% [markdown]
# ##### llamado de la función

# %%
l=7              #longitud
q=0
d1=1.06
n=5000
rs=1
ti=np.arctan(d1/(l/2))       
tf=ti+1*np.pi 
z0=1/np.sqrt((l/2)**2+d1**2)  
y0=(np.sin(np.pi/(2)))/np.sqrt((l/2)**2+d1**2)
y0=y0+.7
sol1=geodesicas(d1,l,rs,n,ti,tf,z0,y0,q)
# Out:
# /Users/marco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: overflow encountered in double_scalars
# /Users/marco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in double_scalars
# /Users/marco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: RuntimeWarning: overflow encountered in double_scalars
# /Users/marco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: RuntimeWarning: invalid value encountered in double_scalars

# %%
d2=1.98
rs=1
ti=np.arctan(d2/(l/2))       
tf=ti+1*np.pi 
z0=1/np.sqrt((l/2)**2+d2**2)  
y0=(np.sin(np.pi/(2)))/np.sqrt((l/2)**2+d2**2)
y0=y0+.19
sol2=geodesicas(d2,l,rs,n,ti,tf,z0,y0,q)

# %%
d3=2.55
rs=1
ti=np.arctan(d3/(l/2))       
tf=ti+3*np.pi 
z0=1/np.sqrt((l/2)**2+d3**2)  
y0=(np.sin(np.pi/(2)))/np.sqrt((l/2)**2+d3**2)
y0=y0+.0962
#y0=y0+.09757
sol3=geodesicas(d3,l,rs,n,ti,tf,z0,y0,q)

# %%
d4=2.9
rs=1
ti=np.arctan(d4/(l/2))       
tf=ti+1.5*np.pi 
z0=1/np.sqrt((l/2)**2+d4**2)  
y0=(np.sin(np.pi/(2)))/np.sqrt((l/2)**2+d4**2)
y0=y0+.045
sol4=geodesicas(d4,l,rs,n,ti,tf,z0,y0,q)

# %%
plt.figure(figsize=(10,10))
#plt.title("Geodésicas de Schwarzchild",fontsize=18, color = 'black')  
draw_circle = plt.Circle((0.0, 0.0), rs ,fill=False, color='black',linewidth=2, linestyle="solid")
plt.gcf().gca().add_artist(draw_circle)
plt.xlim(-3.5, 3.5)
plt.ylim(-3.5, 3.5)
plt.plot(sol1[0],sol1[1], color='red',label="b=1")
plt.plot(sol2[0],sol2[1], color='blue',label="b=2")
plt.plot(sol3[0],sol3[1], color='green',label="$b=b_c$")
plt.plot(sol4[0],sol4[1], color='yellow',label="b=3")
plt.legend(loc='upper left')
plt.xlabel("$x/r_s$",fontsize=15, color = 'black')            
plt.ylabel("$y/r_s$",fontsize=15, color = 'black')   
#plt.grid(color = '0.5', linestyle = '--', linewidth = 1)
plt.savefig('RGK-S.pdf')

# %% [markdown]
# ## Análisis de los datos de Comsol

# %% [markdown]
# #### Schwarzschild

# %%
dat1= pd.read_excel('b1new.xlsx')
dat1=np.array(dat1)

# %%
dat2= pd.read_excel('b2.xlsx')
dat2=np.array(dat2)

# %%
datp_s= pd.read_excel('b26new.xlsx')
datp_s=np.array(datp_s)

# %%
dat3= pd.read_excel('b3.xlsx')
dat3=np.array(dat3)

# %%
malla_x=800
malla_y=800
L=7

# %%
def den_funcion(dat,malla_x,malla_y,L):
    x=dat[:,0]
    y=dat[:,1]
    z=dat[:,2]
    den=np.zeros([malla_x,malla_y])
    z_new=np.zeros([malla_x,malla_y])
    z_final=np.zeros([malla_x,malla_y])
    x=x*malla_x/L
    y=y*malla_x/L
    for i in range(len(x)):   
        if z[i]>1:
            z[i]=1
        a=int(int(x[i])+malla_x/2-1)
        b=-int(int(y[i])+malla_y/2-1)
        den[a,b]=den[a,b]+1
        z_new[a,b]=z_new[a,b]+z[i]
        z_final[b,a]=z_new[a,b]/den[a,b]
    return z_final

# %%
S1=den_funcion(dat1,350,350,L)
S2=den_funcion(dat2,malla_x,malla_y,L)
S3=den_funcion(dat3,malla_x,malla_y,L)

# %%
Sp_s=den_funcion(datp_s,600,600,L)

# %%
plt.figure(figsize=(14,14))

plt.subplot(221)
plt.imshow(S1,interpolation='bilinear',cmap='jet',extent=(-3.5,3.5,-3.5,3.5))
plt.xlabel("$x/r_s$",fontsize=15, color = 'black')
plt.ylabel("$y/r_s$",fontsize=15, color = 'black')
plt.plot(sol1[0],sol1[1], color='white',linewidth=3)
plt.xlim(-3.5, 3.5)
plt.ylim(-3.5, 3.5)
plt.xticks([-3.0, -2, -1, 0,1,2,3],fontsize=10, color = 'black')
plt.yticks([-3.0, -2, -1, 0,1,2,3],fontsize=10, color = 'black')
plt.title(r"$b=1r_s$",fontsize = 15, color = 'black', verticalalignment = 'baseline', horizontalalignment = 'center')
#plt.plot(z,z)
plt.text(-3.4, 3.2, "a)",fontsize=14, color = 'white')
draw_circle = plt.Circle((0.0, 0.0), 1.05,fill=False, color='white',linewidth=2, linestyle="solid")
plt.gcf().gca().add_artist(draw_circle)
draw_circle = plt.Circle((0.0, 0.0), 1.5,fill=False, color='white',linewidth=1.5, linestyle="dashed")
plt.gcf().gca().add_artist(draw_circle)

plt.subplot(222)
plt.imshow(S2,interpolation='bilinear',cmap='jet',extent=(-3.5,3.5,-3.5,3.5))
plt.xlabel("$x/r_s$",fontsize=15, color = 'black')
plt.ylabel("$y/r_s$",fontsize=15, color = 'black')
plt.plot(sol2[0],sol2[1], color='white',linewidth=3)
#plt.plot(XX,YY, color='white',linewidth=3)
plt.xlim(-3.5, 3.5)
plt.ylim(-3.5, 3.5)
plt.xticks([-3.0, -2, -1, 0,1,2,3],fontsize=10, color = 'black')
plt.yticks([-3.0, -2, -1, 0,1,2,3],fontsize=10, color = 'black')
plt.title(r"$b=2r_s$",fontsize = 15, color = 'black', verticalalignment = 'baseline', horizontalalignment = 'center')
plt.text(-3.4, 3.2, "b)",fontsize=14, color = 'white')
draw_circle = plt.Circle((0.0, 0.0), 1.05,fill=False, color='white',linewidth=2, linestyle="solid")
plt.gcf().gca().add_artist(draw_circle)
draw_circle = plt.Circle((0.0, 0.0), 1.5,fill=False, color='white',linewidth=1.5, linestyle="dashed")
plt.gcf().gca().add_artist(draw_circle)

plt.subplot(223)
plt.imshow(Sp_s, interpolation='bilinear', cmap='jet',extent=(-3.5,3.5,-3.5,3.5))
plt.xlabel("$x/r_s$",fontsize=15, color = 'black')
plt.ylabel("$y/r_s$",fontsize=15, color = 'black')
plt.plot(sol3[0],sol3[1], color='white',linewidth=3)
plt.xlim(-3.5, 3.5)
plt.ylim(-3.5, 3.5)
plt.xticks([-3.0, -2, -1, 0,1,2,3],fontsize=10, color = 'black')
plt.yticks([-3.0, -2, -1, 0,1,2,3],fontsize=10, color = 'black')
plt.title(r"$b=2.6r_s$",fontsize = 15, color = 'black', verticalalignment = 'baseline', horizontalalignment = 'center')
plt.text(-3.4, 3.2, "c)",fontsize=14, color = 'white')
draw_circle = plt.Circle((0.0, 0.0), 1.05,fill=False, color='white',linewidth=2, linestyle="solid")
plt.gcf().gca().add_artist(draw_circle)
draw_circle = plt.Circle((0.0, 0.0), 1.5,fill=False, color='white',linewidth=1.5, linestyle="dashed")
plt.gcf().gca().add_artist(draw_circle)

plt.subplot(224)
plt.imshow(S3, interpolation='bilinear', cmap='jet',extent=(-3.5,3.5,-3.5,3.5))
plt.xlabel("$x/r_s$",fontsize=15, color = 'black')
plt.ylabel("$y/r_s$",fontsize=15, color = 'black')
plt.plot(sol4[0],sol4[1], color='white',linewidth=3)
plt.xlim(-3.5, 3.5)
plt.ylim(-3.5, 3.5)
plt.xticks([-3.0, -2, -1, 0,1,2,3],fontsize=10, color = 'black')
plt.yticks([-3.0, -2, -1, 0,1,2,3],fontsize=10, color = 'black')
plt.title(r"$b=3r_s$",fontsize = 15, color = 'black', verticalalignment = 'baseline', horizontalalignment = 'center')
plt.text(-3.4, 3.2, "d)",fontsize=14, color = 'white')
draw_circle = plt.Circle((0.0, 0.0), 1.05,fill=False, color='white',linewidth=2, linestyle="solid")
plt.gcf().gca().add_artist(draw_circle)
draw_circle = plt.Circle((0.0, 0.0), 1.5,fill=False, color='white',linewidth=1.5, linestyle="dashed")
plt.gcf().gca().add_artist(draw_circle)
#cax = plt.axes([.93, 0.1, 0.024, 0.8])
cax = plt.axes([.113, .055, 0.8, 0.02])
plt.colorbar(cax=cax,orientation="horizontal")

plt.savefig('Grafica1.pdf')
plt.show()

# %% [markdown]
# #### Reissner-Nordstrom

# %%
q=0
d3=2.59
rs=1
ti=np.arctan(d3/(l/2))       
tf=ti+1.5*np.pi 
z0=1/np.sqrt((l/2)**2+d3**2)  
y0=(np.sin(np.pi/(2)))/np.sqrt((l/2)**2+d3**2)
#y0=y0+.098026
y0=y0+.085
sol1R=geodesicas(d3,l,rs,n,ti,tf,z0,y0,q)

for j in range(0,n):
        if (sol1R[0][j]**2+sol1R[1][j]**2) < 1.1:
            sol1R[0][j]=np.nan
            sol1R[1][j]=np.nan

# %%
sol1R[0][0],1.1, n
# Out:
# (3.4999999999999996, 1.1, 5000)

# %%
d2=1.98
rs=1
ti=np.arctan(d2/(l/2))       
tf=ti+0.59*np.pi 
z0=1/np.sqrt((l/2)**2+d2**2)  
y0=(np.sin(np.pi/(2)))/np.sqrt((l/2)**2+d2**2)
y0=y0+.2
sol2R=geodesicas(d2,l,rs,n,ti,tf,z0,y0,q)

# %%
d3=2
rs=1
q=1/2*rs
ti=np.arctan(d3/(l/2))       
tf=ti+4*np.pi 
z0=1/np.sqrt((l/2)**2+d3**2)  
y0=(np.sin(np.pi/(2)))/np.sqrt((l/2)**2+d3**2)
y0=y0+.20145
sol3R=geodesicas(d3,l,rs,n,ti,tf,z0,y0,q)

# %%
rh=rs/2+np.sqrt(rs**2-4*q**2)/2
rh
# Out:
# 0.5

# %%
d4=2.50
rs=1
q=1/2*rs
ti=np.arctan(d4/(l/2))       
tf=ti+5*np.pi 
z0=1/np.sqrt((l/2)**2+d4**2)  
y0=(np.sin(np.pi/(2)))/np.sqrt((l/2)**2+d4**2)
y0=y0+.08
sol4R=geodesicas(d4,l,rs,n,ti,tf,z0,y0,q)

for j in range(0,n):
        if j>1580:
            sol4R[0][j]=np.nan
            sol4R[1][j]=np.nan

# %%
j
# Out:
# 4999

# %%
plt.figure(figsize=(10,10))
#plt.title("Geodésicas de Schwarzchild",fontsize=18, color = 'black')  
#draw_circle = plt.Circle((0.0, 0.0), rs ,fill=False, color='black',linewidth=2, linestyle="solid",label="Schwarzchild BH")
#plt.gcf().gca().add_artist(draw_circle)
draw_circle = plt.Circle((0.0, 0.0), rs/2 ,fill=True, color='black',linewidth=2, linestyle="solid",label="Reissner-Nordstrom BH")
plt.gcf().gca().add_artist(draw_circle)
plt.xlim(-3.5, 3.5)
plt.ylim(-3.5, 3.5)
plt.plot(sol1R[0],sol1R[1], color='green',label="Schwarzchild, $b=b_c$")
plt.plot(sol2R[0],sol2R[1], color='blue',label="Schwarzchild, b=2")
plt.plot(sol3R[0],sol3R[1], color='Yellow',label="Reissner-Nordstrom, $q=r_s/2$, $b=b_c$")
plt.plot(sol4R[0],sol4R[1], color='red',label="Reissner-Nordstrom, b=1")
#plt.plot(sol4R[0][1580],sol4R[1][1580], marker="o",color='black',label="Reissner-Nordstrom, b=1")
plt.legend(loc='upper left')
plt.xlabel("$x/r_s$",fontsize=15, color = 'black')            
plt.ylabel("$y/r_s$",fontsize=15, color = 'black')   
#plt.grid(color = '0.5', linestyle = '--', linewidth = 1)
plt.savefig('RGK-SRN.pdf')

# %%
dat26RN= pd.read_excel('b26RN-qmin.xlsx')
dat26RN=np.array(dat26RN)

# %%
dat2RN= pd.read_excel('b2RN-qmax.xlsx')
dat2RN=np.array(dat2RN)

# %%
dat1RN= pd.read_excel('RN_2.5bnew.xlsx')
dat1RN=np.array(dat1RN)

# %%
dat2RNmin= pd.read_excel('b2RN-qmin.xlsx')
dat2RNmin=np.array(dat2RNmin)

# %%
malla_x=800
malla_y=800
L=7

# %%
S2p6RN=den_funcion(dat26RN,malla_x,malla_y,L)
S2RN=den_funcion(dat2RN,malla_x,malla_y,L)
S2RNmin=den_funcion(dat2RNmin,malla_x,malla_y,L)

# %%
S1RN=den_funcion(dat1RN,600,600,L)

# %%
plt.figure(figsize=(16,14))

plt.subplot(221)
plt.imshow(Sp_s, interpolation='bilinear', cmap='jet',extent=(-3.5,3.5,-3.5,3.5))
plt.xlabel("$x/r_s$",fontsize=15, color = 'black')
plt.ylabel("$y/r_s$",fontsize=15, color = 'black')
plt.plot(sol3[0],sol3[1], color='white',linewidth=3)
plt.xlim(-3.5, 3.5)
plt.ylim(-3.5, 3.5)
plt.xticks([-3.0, -2, -1, 0,1,2,3],fontsize=10, color = 'black')
plt.yticks([-3.0, -2, -1, 0,1,2,3],fontsize=10, color = 'black')
plt.title(r"$b=2.6r_s, \ q=0$",fontsize = 15, color = 'black', verticalalignment = 'baseline', horizontalalignment = 'center')
plt.text(-3.4, 3.2, "a)",fontsize=14, color = 'white')
draw_circle = plt.Circle((0.0, 0.0), 1.07,fill=False, color='white',linewidth=2.5, linestyle="solid")
plt.gcf().gca().add_artist(draw_circle)
draw_circle = plt.Circle((0.0, 0.0), 1.5,fill=False, color='white',linewidth=1.5, linestyle="dashed")
plt.gcf().gca().add_artist(draw_circle)

plt.subplot(222)
plt.imshow(S2RNmin,interpolation='bilinear',cmap='jet',extent=(-3.5,3.5,-3.5,3.5))
plt.xlabel("$x/r_s$",fontsize=15, color = 'black')
plt.ylabel("$y/r_s$",fontsize=15, color = 'black')
plt.xlim(-3.5, 3.5)
plt.ylim(-3.5, 3.5)
plt.plot(sol2R[0],sol2R[1], color='white',linewidth=3)
plt.xticks([-3.0, -2, -1, 0,1,2,3],fontsize=10, color = 'black')
plt.yticks([-3.0, -2, -1, 0,1,2,3],fontsize=10, color = 'black')
plt.title(r"$b=2r_s,\ q=0$",fontsize = 15, color = 'black', verticalalignment = 'baseline', horizontalalignment = 'center')
plt.text(-3.4, 3.2, "b)",fontsize=14, color = 'white')
draw_circle = plt.Circle((0.0, 0.0), 1.1,fill=False, color='white',linewidth=2.5, linestyle="solid")
plt.gcf().gca().add_artist(draw_circle)
draw_circle = plt.Circle((0.0, 0.0), 1.5,fill=False, color='white',linewidth=1.5, linestyle="dashed")
plt.gcf().gca().add_artist(draw_circle)


plt.subplot(223)
plt.imshow(S2RN,interpolation='bilinear',cmap='jet',extent=(-3.5,3.5,-3.5,3.5))
plt.xlabel("$x/r_s$",fontsize=15, color = 'black')
plt.ylabel("$y/r_s$",fontsize=15, color = 'black')
plt.plot(sol3R[0],sol3R[1], color='white',linewidth=3)
plt.xlim(-3.5, 3.5)
plt.ylim(-3.5, 3.5)
plt.xticks([-3.0, -2, -1, 0,1,2,3],fontsize=10, color = 'black')
plt.yticks([-3.0, -2, -1, 0,1,2,3],fontsize=10, color = 'black')
plt.title(r"$b=2r_s, \ q=r_s/2$",fontsize = 15, color = 'black', verticalalignment = 'baseline', horizontalalignment = 'center')
plt.text(-3.4, 3.2, "c)",fontsize=14, color = 'white')
draw_circle = plt.Circle((0.0, 0.0), .5+0.05*3,fill=False, color='white',linewidth=2, linestyle="solid")
plt.gcf().gca().add_artist(draw_circle)
draw_circle = plt.Circle((0.0, 0.0), .65*1.5,fill=False, color='white',linewidth=1.5, linestyle="dashed")
plt.gcf().gca().add_artist(draw_circle)


plt.subplot(224)
plt.imshow(S1RN,interpolation='bilinear',cmap='jet',extent=(-3.5,3.5,-3.5,3.5))
plt.xlabel("$x/r_s$",fontsize=15, color = 'black')
plt.ylabel("$y/r_s$",fontsize=15, color = 'black')
plt.plot(sol4R[0],sol4R[1], color='white',linewidth=3)
plt.xlim(-3.5, 3.5)
plt.ylim(-3.5, 3.5)
plt.xticks([-3.0, -2, -1, 0,1,2,3],fontsize=10, color = 'black')
plt.yticks([-3.0, -2, -1, 0,1,2,3],fontsize=10, color = 'black')
plt.text(-3.4, 3.2, "d)",fontsize=14, color = 'white')
plt.title(r"$b=2.5r_s,\ q=r_s/2$",fontsize = 15, color = 'black', verticalalignment = 'baseline', horizontalalignment = 'center')
draw_circle = plt.Circle((0.0, 0.0), .5+0.05*3,fill=False, color='white',linewidth=2, linestyle="solid")
plt.gcf().gca().add_artist(draw_circle)
draw_circle = plt.Circle((0.0, 0.0), .65*1.5,fill=False, color='white',linewidth=1.5, linestyle="dashed")
plt.gcf().gca().add_artist(draw_circle)


#plt.suptitle('Distribución de Campo Eléctrico',fontsize=15, verticalalignment = 'baseline', horizontalalignment = 'center')
cax = plt.axes([.113, .055, 0.8, 0.02])
#cax = plt.axes([.93, 0.1, 0.024, 0.8])
plt.colorbar(cax=cax, orientation="horizontal")

plt.savefig('Grafica2.pdf')
plt.show()

# %%
plt.figure(figsize=(10,10))

plt.imshow(Sp_s, interpolation='bilinear', cmap='jet',extent=(-3.5,3.5,-3.5,3.5))
plt.xlabel("$x/r_s$",fontsize=15, color = 'black')
plt.ylabel("$y/r_s$",fontsize=15, color = 'black')
plt.plot(sol1R[0],sol1R[1], color='white',linewidth=3)
plt.xlim(-3.5, 3.5)
plt.ylim(-3.5, 3.5)
plt.xticks([-3.0, -2, -1, 0,1,2,3],fontsize=10, color = 'black')
plt.yticks([-3.0, -2, -1, 0,1,2,3],fontsize=10, color = 'black')
plt.title(r"$b=2.6r_s, \ q=\frac{r_s}{\infty}$",fontsize = 15, color = 'black', verticalalignment = 'baseline', horizontalalignment = 'center')
plt.text(-3.4, 3.2, "a)",fontsize=14, color = 'white')
draw_circle = plt.Circle((0.0, 0.0), 1.07,fill=False, color='white',linewidth=2.5, linestyle="solid")
plt.gcf().gca().add_artist(draw_circle)
draw_circle = plt.Circle((0.0, 0.0), 1.5,fill=False, color='white',linewidth=1.5, linestyle="dashed")
plt.gcf().gca().add_artist(draw_circle)

#plt.suptitle('Distribución de Campo Eléctrico',fontsize=15, verticalalignment = 'baseline', horizontalalignment = 'center')
#cax = plt.axes([.113, .055, 0.8, 0.02])
cax = plt.axes([.93, 0.1, 0.024, 0.8])
plt.colorbar(cax=cax) #orientation="horizontal")

plt.savefig('Grafica2a.pdf')
plt.show()

# %%
plt.figure(figsize=(10,10))

plt.imshow(S2RNmin,interpolation='bilinear',cmap='jet',extent=(-3.5,3.5,-3.5,3.5))
plt.xlabel("$x/r_s$",fontsize=15, color = 'black')
plt.ylabel("$y/r_s$",fontsize=15, color = 'black')
plt.xlim(-3.5, 3.5)
plt.ylim(-3.5, 3.5)
plt.plot(sol2R[0],sol2R[1], color='white',linewidth=3)
plt.xticks([-3.0, -2, -1, 0,1,2,3],fontsize=10, color = 'black')
plt.yticks([-3.0, -2, -1, 0,1,2,3],fontsize=10, color = 'black')
plt.title(r"$b=2r_s,\ q=\frac{r_s}{\infty}$",fontsize = 15, color = 'black', verticalalignment = 'baseline', horizontalalignment = 'center')
plt.text(-3.4, 3.2, "c)",fontsize=14, color = 'white')
draw_circle = plt.Circle((0.0, 0.0), 1.1,fill=False, color='white',linewidth=2.5, linestyle="solid")
plt.gcf().gca().add_artist(draw_circle)
draw_circle = plt.Circle((0.0, 0.0), 1.5,fill=False, color='white',linewidth=1.5, linestyle="dashed")
plt.gcf().gca().add_artist(draw_circle)

#plt.suptitle('Distribución de Campo Eléctrico',fontsize=15, verticalalignment = 'baseline', horizontalalignment = 'center')
#cax = plt.axes([.113, .055, 0.8, 0.02])
cax = plt.axes([.93, 0.1, 0.024, 0.8])
plt.colorbar(cax=cax) #orientation="horizontal")

plt.savefig('Grafica2b.pdf')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.imshow(S2RN,interpolation='bilinear',cmap='jet',extent=(-3.5,3.5,-3.5,3.5))
plt.xlabel("$x/r_s$",fontsize=15, color = 'black')
plt.ylabel("$y/r_s$",fontsize=15, color = 'black')
plt.plot(sol3R[0],sol3R[1], color='white',linewidth=3)
plt.xlim(-3.5, 3.5)
plt.ylim(-3.5, 3.5)
plt.xticks([-3.0, -2, -1, 0,1,2,3],fontsize=10, color = 'black')
plt.yticks([-3.0, -2, -1, 0,1,2,3],fontsize=10, color = 'black')
plt.title(r"$b=2r_s, \ q=\frac{r_s}{2}$",fontsize = 15, color = 'black', verticalalignment = 'baseline', horizontalalignment = 'center')
plt.text(-3.4, 3.2, "b)",fontsize=14, color = 'white')
draw_circle = plt.Circle((0.0, 0.0), .5+0.05*3,fill=False, color='white',linewidth=2, linestyle="solid")
plt.gcf().gca().add_artist(draw_circle)
draw_circle = plt.Circle((0.0, 0.0), .65*1.5,fill=False, color='white',linewidth=1.5, linestyle="dashed")
plt.gcf().gca().add_artist(draw_circle)

#plt.suptitle('Distribución de Campo Eléctrico',fontsize=15, verticalalignment = 'baseline', horizontalalignment = 'center')
#cax = plt.axes([.113, .055, 0.8, 0.02])
cax = plt.axes([.93, 0.1, 0.024, 0.8])
plt.colorbar(cax=cax) #orientation="horizontal")

plt.savefig('Grafica2c.pdf')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.imshow(S1RN,interpolation='bilinear',cmap='jet',extent=(-3.5,3.5,-3.5,3.5))
plt.xlabel("$x/r_s$",fontsize=15, color = 'black')
plt.ylabel("$y/r_s$",fontsize=15, color = 'black')
plt.plot(sol4R[0],sol4R[1], color='white',linewidth=3)
plt.xlim(-3.5, 3.5)
plt.ylim(-3.5, 3.5)
plt.xticks([-3.0, -2, -1, 0,1,2,3],fontsize=10, color = 'black')
plt.yticks([-3.0, -2, -1, 0,1,2,3],fontsize=10, color = 'black')
plt.text(-3.4, 3.2, "d)",fontsize=14, color = 'white')
plt.title(r"$b=2.5r_s,\ q=\frac{r_s}{2}$",fontsize = 15, color = 'black', verticalalignment = 'baseline', horizontalalignment = 'center')
draw_circle = plt.Circle((0.0, 0.0), .5+0.05*3,fill=False, color='white',linewidth=2, linestyle="solid")
plt.gcf().gca().add_artist(draw_circle)
draw_circle = plt.Circle((0.0, 0.0), .65*1.5,fill=False, color='white',linewidth=1.5, linestyle="dashed")
plt.gcf().gca().add_artist(draw_circle)


#plt.suptitle('Distribución de Campo Eléctrico',fontsize=15, verticalalignment = 'baseline', horizontalalignment = 'center')
#cax = plt.axes([.113, .055, 0.8, 0.02])
cax = plt.axes([.93, 0.1, 0.024, 0.8])
plt.colorbar(cax=cax)#, orientation="horizontal")

plt.savefig('Grafica2d.pdf')
plt.show()

# %%
plt.figure(figsize=(15,12))

plt.subplot(221)
plt.title("Schwarzchild",fontsize=18, color = 'black')  
draw_circle = plt.Circle((0.0, 0.0), rs ,fill=True, color='black',linewidth=2, linestyle="solid")
plt.gcf().gca().add_artist(draw_circle)
plt.xlim(-3.5, 3.5)
plt.ylim(-3.5, 3.5)
plt.plot(sol1[0],sol1[1], color='red',label="$b=1\ r_s$")
plt.plot(sol2[0],sol2[1], color='blue',label="$b=2\ r_s$")
plt.plot(sol3[0],sol3[1], color='green',label="$b=2.6\ r_s$")
plt.plot(sol4[0],sol4[1], color='yellow',label="$b=2.8\ r_s$")
plt.legend(loc='lower right')
plt.xlabel("$x/r_s$",fontsize=15, color = 'black')            
plt.ylabel("$y/r_s$",fontsize=15, color = 'black')   
#plt.grid(color = '0.5', linestyle = '--', linewidth = 1)

plt.subplot(222)
plt.title("Reissner-Nordstrom, $q=r_s/2$",fontsize=18, color = 'black')  
#draw_circle = plt.Circle((0.0, 0.0), rs ,fill=False, color='black',linewidth=2, linestyle="solid",label="Schwarzchild BH")
#plt.gcf().gca().add_artist(draw_circle)
draw_circle = plt.Circle((0.0, 0.0), rs/2 ,fill=True, color='black',linewidth=2, linestyle="solid",label="Reissner-Nordstrom BH")
plt.gcf().gca().add_artist(draw_circle)
plt.xlim(-3.5, 3.5)
plt.ylim(-3.5, 3.5)
plt.plot(sol4R[0],sol4R[1], color='red',label="$b=1\ r_s$")
plt.plot(sol2R[0],sol2R[1], color='blue',label="$b=2\ r_s$")
plt.plot(sol1R[0],sol1R[1], color='green',label="$b=2.6\ r_s$")
plt.plot(sol3R[0],sol3R[1], color='Yellow',label="$b=2.8\ r_s$")
#plt.plot(sol4R[0][1580],sol4R[1][1580], marker="o",color='black',label="Reissner-Nordstrom, b=1")
plt.legend(loc='lower right')
plt.xlabel("$x/r_s$",fontsize=15, color = 'black')            
plt.ylabel("$y/r_s$",fontsize=15, color = 'black')   
#plt.grid(color = '0.5', linestyle = '--', linewidth = 1)
plt.savefig('RGK2.pdf')
